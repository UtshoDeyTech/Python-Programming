# %% [markdown]
# # Working of Counting Sort

# %% [markdown]
# **1. Find out the maximum element (let it be `max`) from the given array.**
#
# ![image.png](attachment:295899b3-78ce-4d3a-8d0d-e9481fe67477.png)
#
# **2. Initialize an array of length `max+1` with all elements 0. This array is used for storing the count of the elements in the array.**
#
# ![image.png](attachment:a166253b-b11c-48c4-935e-ed137ef1ec16.png)
#
# **3. Store the count of each element at their respective index in `count` array
# For example: if the count of element 3 is 2 then, 2 is stored in the 3rd position of `count` array. If element "5" is not present in the array, then 0 is stored in 5th position.**
#
# ![image.png](attachment:ef1a0ed9-172e-404c-9e0c-980a558cd4a1.png)
#
# **4. Store cumulative sum of the elements of the count array. It helps in placing the elements into the correct index of the sorted array.**
#
# ![image.png](attachment:ca564ade-4f87-40cc-a4fc-159d2d0411b7.png)
#
# **5. Find the index of each element of the original array in the count array. This gives the cumulative count. Place the element at the index calculated as shown in figure below.**
#
# ![image.png](attachment:417988f8-fd9d-4192-96ba-738ea00098fa.png)
#
# **6. After placing each element at its correct position, decrease its count by one.**

# %% [markdown]
# ## Counting Sort Algorithm Pseudo code
#
# ![image.png](attachment:61463a57-146c-4b2e-8382-16520d7e5342.png)

# %%
# Counting sort in Python programming


def countingSort(array):
    size = len(array)
    output = [0] * size

    # Initialize count array
    count = [0] * 10

    # Store the count of each elements in count array
    for i in range(0, size):
        count[array[i]] += 1

    # Store the cummulative count
    for i in range(1, 10):
        count[i] += count[i - 1]

    # Find the index of each element of the original array in count array
    # place the elements in output array
    i = size - 1
    while i >= 0:
        output[count[array[i]] - 1] = array[i]
        count[array[i]] -= 1
        i -= 1

    # Copy the sorted elements into original array
    for i in range(0, size):
        array[i] = output[i]

# %%
data = [2, 0, 3, 4, 1]
countingSort(data)
print("Sorted Array in Ascending Order: ")
print(data)
# Out:
# Sorted Array in Ascending Order:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## Counting Sort Complexity
#
# ![image.png](attachment:8f39c68d-5de1-48c0-b437-f2615b852982.png)

# %% [markdown]
# ## Counting Sort Applications
# **Counting sort is used when:**
#
# * there are smaller integers with multiple counts.
# * linear complexity is the need.
