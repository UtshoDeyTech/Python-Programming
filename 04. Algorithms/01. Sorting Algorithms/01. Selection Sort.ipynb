# %% [markdown]
# # Working of Selection Sort

# %% [markdown]
# **1. Set the first element as `minimum`.**
#
# ![image.png](attachment:ea092d36-6c90-4b19-aebe-4106f3a3b7ac.png)
#
# **2. Compare `minimum` with the second element. If the second element is smaller than `minimum`, assign the second element as `minimum`.
# Compare `minimum` with the third element. Again, if the third element is smaller, then assign `minimum` to the third element otherwise do nothing. The process goes on until the last element.**
#
# ![image.png](attachment:4dbf186a-3188-4299-81fc-8214fc787418.png)
#
# **3. After each iteration, `minimum` is placed in the front of the unsorted list.**
#
# ![image.png](attachment:91f96446-cad2-45de-99e7-20b9529f0ab3.png)
#
# **4. For each iteration, indexing starts from the first unsorted element. Step 1 to 3 are repeated until all the elements are placed at their correct positions.**
#
# ![image.png](attachment:38a9170b-a91c-4855-b630-d938b0ef47a4.png)
#
# ![image.png](attachment:fc50480e-84aa-4af3-bf5d-c89782508bf3.png)
#
# ![image.png](attachment:db4237fb-8f41-4182-9043-dba599689b8a.png)
#
# ![image.png](attachment:b493de06-1d3c-4cc6-886f-e645306314ce.png)

# %% [markdown]
# ## Selection Sort Algorithm Pseudo code
#
# ![image.png](attachment:bce36ffd-6227-4757-a19b-5b388dbc52bf.png)

# %%
# Selection sort in Python

def selectionSort(array, size):
   
    for step in range(size):
        min_idx = step

        for i in range(step + 1, size):
         
            # to sort in descending order, change > to < in this line
            # select the minimum element in each loop
            if array[i] < array[min_idx]:
                min_idx = i
         
        # put min at the correct position
        (array[step], array[min_idx]) = (array[min_idx], array[step])

# %%
data = [2, 0, 3, 4, 1]
size = len(data)
selectionSort(data, size)
print('Sorted Array in Ascending Order:')
print(data)
# Out:
# Sorted Array in Ascending Order:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## Selection Sort Complexity
#
# ![image.png](attachment:063bfdd5-0294-4de7-99df-11970998a7cd.png)

# %% [markdown]
# ## Selection Sort Applications
#
# **The selection sort is used when**
# * small list is to be sorted
# * cost of swapping does not matter
# * checking of all the elements is compulsory
# * cost of writing to a memory matters like in flash memory (number of writes/swaps is O(n) as compared to O(n2) of bubble sort)
